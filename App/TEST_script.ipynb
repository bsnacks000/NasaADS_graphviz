# %%
# testing sigma
from utils.prepare_sigma import PrepareSigma

# %%
db_path = 'sqlite:///./data/graph.db'
p = PrepareSigma('stars_islands', db_path)

# %%
p.edges
# Out:
#         id  source  target  weight  size
# 0        0       2       3       1     1
# 1        1       2       4       1     1
# 2        2       2       5       1     1
# 3        3       2       6       1     1
# 4        4       2       7       1     1
# 5        5       2       8       1     1
# 6        6       2       9       1     1
# 7        7       2      10       1     1
# 8        8       2      11       1     1
# 9        9       2      12       1     1
# 10      10       2      13       1     1
# 11      11       2      14       1     1
# 12      12       2      15       1     1
# 13      13       2      16       1     1
# 14      14       2      17       1     1
# 15      15       2      18       1     1
# 16      16       2      19       1     1
# 17      17       2      20       1     1
# 18      18       2      21       1     1
# 19      19       2      22       1     1
# 20      20       2      23       1     1
# 21      21       2      24       1     1
# ...
